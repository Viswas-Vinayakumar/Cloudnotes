# %% [markdown]
# <a href="https://colab.research.google.com/github/Viswas-Vinayakumar/Cloudnotes/blob/main/lagchainpractice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install -qU langchain-groq
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.5/137.5 kB 1.6 MB/s eta 0:00:00

# %%
from langchain_groq import ChatGroq
from google.colab import userdata

llm = ChatGroq(
    api_key=userdata.get('langchaingroqapi'),
    model="openai/gpt-oss-120b",
    temperature=0,
    max_tokens=None,
)

# %%
print(llm.invoke('who is the CEO of Microsoft?').content)
# Out:
# Satya Nadella is the Chief Executive Officer of Microsoft. He has held the position since February 2014.

# %%
# !pip install langchain_core

# %%
import langchain_core

# %%
from langchain_core.output_parsers import StrOutputParser
from langchain_groq import ChatGroq

llm = ChatGroq(
    api_key=userdata.get('langchaingroqapi'),
    model="openai/gpt-oss-120b",
    temperature=0,
    max_tokens=1000,
)

parser = StrOutputParser()
chain = llm|parser
response = chain.invoke('Explain the story of krishna on how he went from a cowheard boy to the king of Madhura')
print (response)
# Out:
# ### Krishna’s Journey – From a Cow‑herd Boy to the Ruler of Madhura (Mathura)
#
# > **“From the fields of Vrindavan to the throne of Madhura, the life of Krishna is a tapestry of divine play (lila), heroic deeds, and the ever‑lasting message that love and righteousness triumph over darkness.”**
#
# Below is a concise, step‑by‑step retelling of the most widely‑recounted episodes that trace how the infant‑god‑hero, raised as a simple cow‑herd, eventually became the sovereign of Madhura (the ancient city better known today as **Mathura**).
#
# ---
#
# ## 1. Birth in a Prison – The Prophecy
#
# | Event | Key Points |
# |-------|------------|
# | **Parents** | Devaki (daughter of King Ugrasena) and Vasudeva, a noble of the Yadava clan. |
# | **The Curse** | The tyrant king **Kamsa**, Devaki’s brother, learns from a prophecy that Devaki’s eighth son will kill him. In terror, he imprisons the couple and kills the first six children. |
# ...

# %%
LANGCHAIN_API_KEY=userdata.get('APIlangchain')
LANGCHAIN_PROJECT = "project"

# %%
import os
from google.colab import userdata

os.environ["LANGSMITH_TRACING"] = "true"
os.environ["LANGSMITH_ENDPOINT"] = "https://api.smith.langchain.com"
os.environ["LANGSMITH_API_KEY"] = userdata.get('APIlangchain')
os.environ["LANGSMITH_PROJECT"] = "project"
from langchain_core.output_parsers import StrOutputParser
from langchain_groq import ChatGroq

llm = ChatGroq(
    api_key=userdata.get('langchaingroqapi'),
    model="openai/gpt-oss-120b",
    temperature=0,
    max_tokens=None,
)

parser = StrOutputParser()
chain = llm|parser
response = chain.invoke('Explain the story of krishna on how he went from a cowheard boy to the king of Madhura')
print (response)
# Out:
# ## Krishna’s Journey – From a Cow‑herd Boy to the King of Madhura
#
# The story of **Lord Krishna** is told in many ancient texts – the *Bhagavata‑Purana*, *Vishnu‑Purana*, *Harivamsa* and the *Mahābhārata*.  While the details differ slightly from one source to another, the main outline is the same: a divine child who grows up among cows, performs miraculous deeds, defeats the tyrant Kamsa, and finally establishes a righteous kingdom called **Madhura** (the “sweet” city, another name for Mathura).
#
# Below is a concise, chronological retelling that follows the traditional narrative while highlighting the key turning points that transform the cow‑herd boy into a sovereign ruler.
#
# ---
#
# ### 1. Divine Birth and the Threat of Kamsa
#
# | Event | Significance |
# |-------|--------------|
# ...

# %%
from langsmith import Client
print([p.name for p in Client().list_projects()])
# Out:
# ['project']

# %%
from langchain_core.tracers.langchain import wait_for_all_tracers
wait_for_all_tracers()
